# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
API_KEY = os.getenv("dark_sky_api_key")
url = f'https://api.darksky.net/forecast/{API_KEY}/37.8267,-122.4233'

response = requests.get(url)
data = response.json()
data
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1561431143,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 170,
#   'nearestStormBearing': 52,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 62.37,
#   'apparentTemperature': 62.37,
#   'dewPoint': 52.16,
#   'humidity': 0.69,
#   'pressure': 1009.65,
#   'windSpeed': 8.46,
#   'windGust': 11.28,
#   'windBearing': 258,
#   'cloudCover': 0.64,
#   'uvIndex': 0,
#   'visibility': 7.857,
#   'ozone': 336.6},
#  'minutely': {'summary': 'Mostly cloudy for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1561431120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561431960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561432980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561433940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1561434720, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1561428000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.92,
#     'apparentTemperature': 62.92,
#     'dewPoint': 52.35,
#     'humidity': 0.68,
#     'pressure': 1009.74,
#     'windSpeed': 9.09,
#     'windGust': 12.17,
#     'windBearing': 257,
#     'cloudCover': 0.59,
#     'uvIndex': 0,
#     'visibility': 8.289,
#     'ozone': 337.3},
#    {'time': 1561431600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.29,
#     'apparentTemperature': 62.29,
#     'dewPoint': 52.13,
#     'humidity': 0.69,
#     'pressure': 1009.64,
#     'windSpeed': 8.37,
#     'windGust': 11.15,
#     'windBearing': 258,
#     'cloudCover': 0.64,
#     'uvIndex': 0,
#     'visibility': 7.794,
#     'ozone': 336.5},
#    {'time': 1561435200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.45,
#     'apparentTemperature': 61.45,
#     'dewPoint': 51.91,
#     'humidity': 0.71,
#     'pressure': 1009.59,
#     'windSpeed': 7.9,
#     'windGust': 10.73,
#     'windBearing': 253,
#     'cloudCover': 0.8,
#     'uvIndex': 0,
#     'visibility': 8.043,
#     'ozone': 335.9},
#    {'time': 1561438800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.48,
#     'apparentTemperature': 60.48,
#     'dewPoint': 51.72,
#     'humidity': 0.73,
#     'pressure': 1009.87,
#     'windSpeed': 7.96,
#     'windGust': 11.37,
#     'windBearing': 241,
#     'cloudCover': 0.91,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.6},
#    {'time': 1561442400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 59.82,
#     'apparentTemperature': 59.82,
#     'dewPoint': 51.63,
#     'humidity': 0.74,
#     'pressure': 1010.14,
#     'windSpeed': 7.9,
#     'windGust': 11.83,
#     'windBearing': 231,
#     'cloudCover': 0.96,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 335.6},
#    {'time': 1561446000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.56,
#     'apparentTemperature': 59.56,
#     'dewPoint': 51.47,
#     'humidity': 0.75,
#     'pressure': 1009.97,
#     'windSpeed': 7.71,
#     'windGust': 11.92,
#     'windBearing': 229,
#     'cloudCover': 0.93,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 336.2},
#    {'time': 1561449600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 59.39,
#     'apparentTemperature': 59.39,
#     'dewPoint': 51.31,
#     'humidity': 0.75,
#     'pressure': 1009.84,
#     'windSpeed': 7.4,
#     'windGust': 11.77,
#     'windBearing': 228,
#     'cloudCover': 0.9,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 337.2},
#    {'time': 1561453200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.16,
#     'apparentTemperature': 59.16,
#     'dewPoint': 51.09,
#     'humidity': 0.75,
#     'pressure': 1009.6,
#     'windSpeed': 7.07,
#     'windGust': 11.4,
#     'windBearing': 228,
#     'cloudCover': 0.87,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 338.6},
#    {'time': 1561456800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.41,
#     'apparentTemperature': 58.41,
#     'dewPoint': 50.78,
#     'humidity': 0.76,
#     'pressure': 1009.51,
#     'windSpeed': 6.8,
#     'windGust': 10.96,
#     'windBearing': 221,
#     'cloudCover': 0.73,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 341},
#    {'time': 1561460400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 57.73,
#     'apparentTemperature': 57.73,
#     'dewPoint': 50.37,
#     'humidity': 0.76,
#     'pressure': 1009.51,
#     'windSpeed': 6.59,
#     'windGust': 10.46,
#     'windBearing': 239,
#     'cloudCover': 0.56,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344},
#    {'time': 1561464000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 56.87,
#     'apparentTemperature': 56.87,
#     'dewPoint': 50.04,
#     'humidity': 0.78,
#     'pressure': 1009.56,
#     'windSpeed': 6.36,
#     'windGust': 10.07,
#     'windBearing': 241,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 345.9},
#    {'time': 1561467600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.99,
#     'apparentTemperature': 56.99,
#     'dewPoint': 49.99,
#     'humidity': 0.77,
#     'pressure': 1009.75,
#     'windSpeed': 5.93,
#     'windGust': 9.55,
#     'windBearing': 239,
#     'cloudCover': 0.42,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 346.1},
#    {'time': 1561471200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 58.39,
#     'apparentTemperature': 58.39,
#     'dewPoint': 50.03,
#     'humidity': 0.74,
#     'pressure': 1010,
#     'windSpeed': 5.52,
#     'windGust': 9.44,
#     'windBearing': 239,
#     'cloudCover': 0.26,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 345.4},
#    {'time': 1561474800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 60.54,
#     'apparentTemperature': 60.54,
#     'dewPoint': 50.01,
#     'humidity': 0.68,
#     'pressure': 1010.22,
#     'windSpeed': 5.65,
#     'windGust': 9.46,
#     'windBearing': 247,
#     'cloudCover': 0.13,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 344.5},
#    {'time': 1561478400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.61,
#     'apparentTemperature': 61.61,
#     'dewPoint': 50.74,
#     'humidity': 0.67,
#     'pressure': 1010.49,
#     'windSpeed': 5.61,
#     'windGust': 7.75,
#     'windBearing': 251,
#     'cloudCover': 0.22,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 343.4},
#    {'time': 1561482000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.7,
#     'apparentTemperature': 63.7,
#     'dewPoint': 51.06,
#     'humidity': 0.63,
#     'pressure': 1010.83,
#     'windSpeed': 6.24,
#     'windGust': 8.29,
#     'windBearing': 252,
#     'cloudCover': 0.28,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 342},
#    {'time': 1561485600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.34,
#     'apparentTemperature': 65.34,
#     'dewPoint': 51.36,
#     'humidity': 0.61,
#     'pressure': 1011.11,
#     'windSpeed': 7.09,
#     'windGust': 9.31,
#     'windBearing': 250,
#     'cloudCover': 0.32,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 341},
#    {'time': 1561489200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.47,
#     'apparentTemperature': 66.47,
#     'dewPoint': 51.68,
#     'humidity': 0.59,
#     'pressure': 1011.15,
#     'windSpeed': 8.28,
#     'windGust': 11.02,
#     'windBearing': 240,
#     'cloudCover': 0.38,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 340.6},
#    {'time': 1561492800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.17,
#     'apparentTemperature': 67.17,
#     'dewPoint': 51.96,
#     'humidity': 0.58,
#     'pressure': 1011.03,
#     'windSpeed': 9.64,
#     'windGust': 13.2,
#     'windBearing': 267,
#     'cloudCover': 0.44,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 340.5},
#    {'time': 1561496400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.51,
#     'apparentTemperature': 67.51,
#     'dewPoint': 52.18,
#     'humidity': 0.58,
#     'pressure': 1010.91,
#     'windSpeed': 10.8,
#     'windGust': 15.31,
#     'windBearing': 261,
#     'cloudCover': 0.49,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 340.5},
#    {'time': 1561500000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.39,
#     'apparentTemperature': 67.39,
#     'dewPoint': 52.34,
#     'humidity': 0.58,
#     'pressure': 1010.85,
#     'windSpeed': 11.55,
#     'windGust': 17.35,
#     'windBearing': 258,
#     'cloudCover': 0.56,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 340.8},
#    {'time': 1561503600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.91,
#     'apparentTemperature': 66.91,
#     'dewPoint': 52.42,
#     'humidity': 0.6,
#     'pressure': 1010.84,
#     'windSpeed': 12.18,
#     'windGust': 19.31,
#     'windBearing': 267,
#     'cloudCover': 0.59,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 341.3},
#    {'time': 1561507200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.58,
#     'apparentTemperature': 65.58,
#     'dewPoint': 52.42,
#     'humidity': 0.62,
#     'pressure': 1010.84,
#     'windSpeed': 12.55,
#     'windGust': 20.54,
#     'windBearing': 269,
#     'cloudCover': 0.5,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 341.7},
#    {'time': 1561510800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.93,
#     'apparentTemperature': 63.93,
#     'dewPoint': 52.27,
#     'humidity': 0.66,
#     'pressure': 1010.92,
#     'windSpeed': 12.42,
#     'windGust': 20.68,
#     'windBearing': 267,
#     'cloudCover': 0.41,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 341.8},
#    {'time': 1561514400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.95,
#     'apparentTemperature': 61.95,
#     'dewPoint': 52.02,
#     'humidity': 0.7,
#     'pressure': 1011.07,
#     'windSpeed': 11.99,
#     'windGust': 20.06,
#     'windBearing': 271,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 341.7},
#    {'time': 1561518000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.08,
#     'apparentTemperature': 61.08,
#     'dewPoint': 51.76,
#     'humidity': 0.71,
#     'pressure': 1011.34,
#     'windSpeed': 11.41,
#     'windGust': 19.13,
#     'windBearing': 269,
#     'cloudCover': 0.47,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 341.9},
#    {'time': 1561521600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.09,
#     'apparentTemperature': 60.09,
#     'dewPoint': 51.5,
#     'humidity': 0.73,
#     'pressure': 1011.77,
#     'windSpeed': 10.59,
#     'windGust': 17.76,
#     'windBearing': 269,
#     'cloudCover': 0.36,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 342.7},
#    {'time': 1561525200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.09,
#     'apparentTemperature': 59.09,
#     'dewPoint': 51.24,
#     'humidity': 0.75,
#     'pressure': 1012.37,
#     'windSpeed': 9.8,
#     'windGust': 16.08,
#     'windBearing': 262,
#     'cloudCover': 0.4,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 343.7},
#    {'time': 1561528800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.15,
#     'apparentTemperature': 58.15,
#     'dewPoint': 50.99,
#     'humidity': 0.77,
#     'pressure': 1012.81,
#     'windSpeed': 9.16,
#     'windGust': 14.93,
#     'windBearing': 265,
#     'cloudCover': 0.45,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.4},
#    {'time': 1561532400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.49,
#     'apparentTemperature': 57.49,
#     'dewPoint': 50.8,
#     'humidity': 0.78,
#     'pressure': 1013.01,
#     'windSpeed': 8.79,
#     'windGust': 14.81,
#     'windBearing': 264,
#     'cloudCover': 0.44,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.3},
#    {'time': 1561536000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.02,
#     'apparentTemperature': 57.02,
#     'dewPoint': 50.65,
#     'humidity': 0.79,
#     'pressure': 1013.03,
#     'windSpeed': 8.59,
#     'windGust': 15.2,
#     'windBearing': 263,
#     'cloudCover': 0.41,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344},
#    {'time': 1561539600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.64,
#     'apparentTemperature': 56.64,
#     'dewPoint': 50.51,
#     'humidity': 0.8,
#     'pressure': 1013.08,
#     'windSpeed': 8.42,
#     'windGust': 15.39,
#     'windBearing': 262,
#     'cloudCover': 0.58,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.2},
#    {'time': 1561543200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 55.99,
#     'apparentTemperature': 55.99,
#     'dewPoint': 50.35,
#     'humidity': 0.81,
#     'pressure': 1013.12,
#     'windSpeed': 8.26,
#     'windGust': 15.1,
#     'windBearing': 262,
#     'cloudCover': 0.6,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 345.4},
#    {'time': 1561546800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 55.35,
#     'apparentTemperature': 55.35,
#     'dewPoint': 50.21,
#     'humidity': 0.83,
#     'pressure': 1013.18,
#     'windSpeed': 8.11,
#     'windGust': 14.62,
#     'windBearing': 261,
#     'cloudCover': 0.65,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 347},
#    {'time': 1561550400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.57,
#     'apparentTemperature': 54.57,
#     'dewPoint': 50.13,
#     'humidity': 0.85,
#     'pressure': 1013.37,
#     'windSpeed': 7.95,
#     'windGust': 14.13,
#     'windBearing': 263,
#     'cloudCover': 0.63,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 348.8},
#    {'time': 1561554000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.59,
#     'apparentTemperature': 54.59,
#     'dewPoint': 50.11,
#     'humidity': 0.85,
#     'pressure': 1013.67,
#     'windSpeed': 7.66,
#     'windGust': 13.6,
#     'windBearing': 261,
#     'cloudCover': 0.38,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 350.4},
#    {'time': 1561557600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.47,
#     'apparentTemperature': 55.47,
#     'dewPoint': 50.14,
#     'humidity': 0.82,
#     'pressure': 1014.06,
#     'windSpeed': 7.46,
#     'windGust': 13.05,
#     'windBearing': 263,
#     'cloudCover': 0.35,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 351.8},
#    {'time': 1561561200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.89,
#     'apparentTemperature': 56.89,
#     'dewPoint': 50.31,
#     'humidity': 0.79,
#     'pressure': 1014.42,
#     'windSpeed': 7.69,
#     'windGust': 12.82,
#     'windBearing': 264,
#     'cloudCover': 0.32,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 352.7},
#    {'time': 1561564800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.23,
#     'apparentTemperature': 58.23,
#     'dewPoint': 50.66,
#     'humidity': 0.76,
#     'pressure': 1014.83,
#     'windSpeed': 8.33,
#     'windGust': 13.08,
#     'windBearing': 265,
#     'cloudCover': 0.31,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 352.5},
#    {'time': 1561568400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.69,
#     'apparentTemperature': 59.69,
#     'dewPoint': 51.13,
#     'humidity': 0.73,
#     'pressure': 1015.2,
#     'windSpeed': 9.5,
#     'windGust': 13.65,
#     'windBearing': 264,
#     'cloudCover': 0.29,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 351.8},
#    {'time': 1561572000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.71,
#     'apparentTemperature': 60.71,
#     'dewPoint': 51.54,
#     'humidity': 0.72,
#     'pressure': 1015.67,
#     'windSpeed': 10.41,
#     'windGust': 14.36,
#     'windBearing': 266,
#     'cloudCover': 0.27,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 351},
#    {'time': 1561575600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.46,
#     'apparentTemperature': 61.46,
#     'dewPoint': 51.77,
#     'humidity': 0.7,
#     'pressure': 1016.03,
#     'windSpeed': 11.21,
#     'windGust': 15.29,
#     'windBearing': 270,
#     'cloudCover': 0.21,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 350.5},
#    {'time': 1561579200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.33,
#     'apparentTemperature': 62.33,
#     'dewPoint': 51.91,
#     'humidity': 0.69,
#     'pressure': 1016.26,
#     'windSpeed': 12.19,
#     'windGust': 16.38,
#     'windBearing': 260,
#     'cloudCover': 0.14,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 350},
#    {'time': 1561582800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.78,
#     'apparentTemperature': 62.78,
#     'dewPoint': 51.91,
#     'humidity': 0.68,
#     'pressure': 1016.37,
#     'windSpeed': 12.78,
#     'windGust': 17.23,
#     'windBearing': 268,
#     'cloudCover': 0.09,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 349.6},
#    {'time': 1561586400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.36,
#     'apparentTemperature': 62.36,
#     'dewPoint': 51.73,
#     'humidity': 0.68,
#     'pressure': 1016.36,
#     'windSpeed': 13.07,
#     'windGust': 17.62,
#     'windBearing': 260,
#     'cloudCover': 0.09,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 349.3},
#    {'time': 1561590000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.78,
#     'apparentTemperature': 61.78,
#     'dewPoint': 51.48,
#     'humidity': 0.69,
#     'pressure': 1016.23,
#     'windSpeed': 13.13,
#     'windGust': 17.73,
#     'windBearing': 278,
#     'cloudCover': 0.13,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 348.9},
#    {'time': 1561593600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.47,
#     'apparentTemperature': 60.47,
#     'dewPoint': 51.3,
#     'humidity': 0.72,
#     'pressure': 1016.14,
#     'windSpeed': 13.1,
#     'windGust': 17.8,
#     'windBearing': 271,
#     'cloudCover': 0.13,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 348.9},
#    {'time': 1561597200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.3,
#     'apparentTemperature': 59.3,
#     'dewPoint': 51.22,
#     'humidity': 0.75,
#     'pressure': 1016.01,
#     'windSpeed': 12.81,
#     'windGust': 17.93,
#     'windBearing': 262,
#     'cloudCover': 0.13,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 349.8},
#    {'time': 1561600800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.73,
#     'apparentTemperature': 57.73,
#     'dewPoint': 51.2,
#     'humidity': 0.79,
#     'pressure': 1016.03,
#     'windSpeed': 12.27,
#     'windGust': 18.04,
#     'windBearing': 286,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 351.1},
#    {'time': 1561604400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57,
#     'apparentTemperature': 57,
#     'dewPoint': 51.23,
#     'humidity': 0.81,
#     'pressure': 1016.13,
#     'windSpeed': 11.61,
#     'windGust': 18.02,
#     'windBearing': 279,
#     'cloudCover': 0.18,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 351.7}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures bottoming out at 62°F on Thursday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1561359600,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561380600,
#     'sunsetTime': 1561433813,
#     'moonPhase': 0.74,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0011,
#     'precipIntensityMaxTime': 1561442400,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperatureHigh': 67.73,
#     'temperatureHighTime': 1561410000,
#     'temperatureLow': 56.87,
#     'temperatureLowTime': 1561464000,
#     'apparentTemperatureHigh': 67.73,
#     'apparentTemperatureHighTime': 1561410000,
#     'apparentTemperatureLow': 56.87,
#     'apparentTemperatureLowTime': 1561464000,
#     'dewPoint': 53.15,
#     'humidity': 0.76,
#     'pressure': 1011.2,
#     'windSpeed': 6.76,
#     'windGust': 12.92,
#     'windGustTime': 1561417200,
#     'windBearing': 249,
#     'cloudCover': 0.53,
#     'uvIndex': 7,
#     'uvIndexTime': 1561406400,
#     'visibility': 7.816,
#     'ozone': 334.7,
#     'temperatureMin': 55.28,
#     'temperatureMinTime': 1561384800,
#     'temperatureMax': 67.73,
#     'temperatureMaxTime': 1561410000,
#     'apparentTemperatureMin': 55.28,
#     'apparentTemperatureMinTime': 1561384800,
#     'apparentTemperatureMax': 67.73,
#     'apparentTemperatureMaxTime': 1561410000},
#    {'time': 1561446000,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561467018,
#     'sunsetTime': 1561520219,
#     'moonPhase': 0.77,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0016,
#     'precipIntensityMaxTime': 1561460400,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperatureHigh': 67.51,
#     'temperatureHighTime': 1561496400,
#     'temperatureLow': 54.57,
#     'temperatureLowTime': 1561550400,
#     'apparentTemperatureHigh': 67.51,
#     'apparentTemperatureHighTime': 1561496400,
#     'apparentTemperatureLow': 54.57,
#     'apparentTemperatureLowTime': 1561550400,
#     'dewPoint': 51.27,
#     'humidity': 0.69,
#     'pressure': 1010.77,
#     'windSpeed': 8.68,
#     'windGust': 20.68,
#     'windGustTime': 1561510800,
#     'windBearing': 255,
#     'cloudCover': 0.48,
#     'uvIndex': 7,
#     'uvIndexTime': 1561492800,
#     'visibility': 10,
#     'ozone': 342,
#     'temperatureMin': 56.87,
#     'temperatureMinTime': 1561464000,
#     'temperatureMax': 67.51,
#     'temperatureMaxTime': 1561496400,
#     'apparentTemperatureMin': 56.87,
#     'apparentTemperatureMinTime': 1561464000,
#     'apparentTemperatureMax': 67.51,
#     'apparentTemperatureMaxTime': 1561496400},
#    {'time': 1561532400,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561553437,
#     'sunsetTime': 1561606623,
#     'moonPhase': 0.8,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.001,
#     'precipIntensityMaxTime': 1561615200,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperatureHigh': 62.78,
#     'temperatureHighTime': 1561582800,
#     'temperatureLow': 53.74,
#     'temperatureLowTime': 1561640400,
#     'apparentTemperatureHigh': 62.78,
#     'apparentTemperatureHighTime': 1561582800,
#     'apparentTemperatureLow': 53.74,
#     'apparentTemperatureLowTime': 1561640400,
#     'dewPoint': 51.05,
#     'humidity': 0.78,
#     'pressure': 1015.22,
#     'windSpeed': 10.08,
#     'windGust': 18.04,
#     'windGustTime': 1561600800,
#     'windBearing': 269,
#     'cloudCover': 0.33,
#     'uvIndex': 8,
#     'uvIndexTime': 1561579200,
#     'visibility': 10,
#     'ozone': 349.2,
#     'temperatureMin': 54.57,
#     'temperatureMinTime': 1561550400,
#     'temperatureMax': 62.78,
#     'temperatureMaxTime': 1561582800,
#     'apparentTemperatureMin': 54.57,
#     'apparentTemperatureMinTime': 1561550400,
#     'apparentTemperatureMax': 62.78,
#     'apparentTemperatureMaxTime': 1561582800},
#    {'time': 1561618800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561639858,
#     'sunsetTime': 1561693026,
#     'moonPhase': 0.84,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0006,
#     'precipIntensityMaxTime': 1561618800,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperatureHigh': 62.1,
#     'temperatureHighTime': 1561672800,
#     'temperatureLow': 54.1,
#     'temperatureLowTime': 1561723200,
#     'apparentTemperatureHigh': 62.1,
#     'apparentTemperatureHighTime': 1561672800,
#     'apparentTemperatureLow': 54.1,
#     'apparentTemperatureLowTime': 1561723200,
#     'dewPoint': 50.75,
#     'humidity': 0.78,
#     'pressure': 1017.97,
#     'windSpeed': 10.77,
#     'windGust': 20.88,
#     'windGustTime': 1561690800,
#     'windBearing': 280,
#     'cloudCover': 0.51,
#     'uvIndex': 7,
#     'uvIndexTime': 1561665600,
#     'visibility': 10,
#     'ozone': 357.4,
#     'temperatureMin': 53.74,
#     'temperatureMinTime': 1561640400,
#     'temperatureMax': 62.1,
#     'temperatureMaxTime': 1561672800,
#     'apparentTemperatureMin': 53.74,
#     'apparentTemperatureMinTime': 1561640400,
#     'apparentTemperatureMax': 62.1,
#     'apparentTemperatureMaxTime': 1561672800},
#    {'time': 1561705200,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1561726281,
#     'sunsetTime': 1561779426,
#     'moonPhase': 0.87,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1561712400,
#     'precipProbability': 0.01,
#     'temperatureHigh': 65.5,
#     'temperatureHighTime': 1561759200,
#     'temperatureLow': 53.06,
#     'temperatureLowTime': 1561809600,
#     'apparentTemperatureHigh': 65.5,
#     'apparentTemperatureHighTime': 1561759200,
#     'apparentTemperatureLow': 53.06,
#     'apparentTemperatureLowTime': 1561809600,
#     'dewPoint': 49.29,
#     'humidity': 0.69,
#     'pressure': 1017.39,
#     'windSpeed': 9.92,
#     'windGust': 21.91,
#     'windGustTime': 1561766400,
#     'windBearing': 286,
#     'cloudCover': 0.21,
#     'uvIndex': 8,
#     'uvIndexTime': 1561752000,
#     'visibility': 10,
#     'ozone': 377.1,
#     'temperatureMin': 54.1,
#     'temperatureMinTime': 1561723200,
#     'temperatureMax': 65.5,
#     'temperatureMaxTime': 1561759200,
#     'apparentTemperatureMin': 54.1,
#     'apparentTemperatureMinTime': 1561723200,
#     'apparentTemperatureMax': 65.5,
#     'apparentTemperatureMaxTime': 1561759200},
#    {'time': 1561791600,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561812704,
#     'sunsetTime': 1561865825,
#     'moonPhase': 0.9,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0001,
#     'precipIntensityMaxTime': 1561834800,
#     'precipProbability': 0.01,
#     'temperatureHigh': 66.3,
#     'temperatureHighTime': 1561849200,
#     'temperatureLow': 54.62,
#     'temperatureLowTime': 1561896000,
#     'apparentTemperatureHigh': 66.3,
#     'apparentTemperatureHighTime': 1561849200,
#     'apparentTemperatureLow': 54.62,
#     'apparentTemperatureLowTime': 1561896000,
#     'dewPoint': 50.25,
#     'humidity': 0.73,
#     'pressure': 1016.66,
#     'windSpeed': 6.06,
#     'windGust': 15.47,
#     'windGustTime': 1561791600,
#     'windBearing': 253,
#     'cloudCover': 0.36,
#     'uvIndex': 6,
#     'uvIndexTime': 1561842000,
#     'visibility': 10,
#     'ozone': 353.1,
#     'temperatureMin': 53.06,
#     'temperatureMinTime': 1561809600,
#     'temperatureMax': 66.3,
#     'temperatureMaxTime': 1561849200,
#     'apparentTemperatureMin': 53.06,
#     'apparentTemperatureMinTime': 1561809600,
#     'apparentTemperatureMax': 66.3,
#     'apparentTemperatureMaxTime': 1561849200},
#    {'time': 1561878000,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1561899130,
#     'sunsetTime': 1561952222,
#     'moonPhase': 0.94,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1561950000,
#     'precipProbability': 0.01,
#     'temperatureHigh': 68.1,
#     'temperatureHighTime': 1561932000,
#     'temperatureLow': 53.01,
#     'temperatureLowTime': 1561982400,
#     'apparentTemperatureHigh': 68.1,
#     'apparentTemperatureHighTime': 1561932000,
#     'apparentTemperatureLow': 53.01,
#     'apparentTemperatureLowTime': 1561982400,
#     'dewPoint': 51.24,
#     'humidity': 0.73,
#     'pressure': 1015.96,
#     'windSpeed': 5.29,
#     'windGust': 15.48,
#     'windGustTime': 1561939200,
#     'windBearing': 233,
#     'cloudCover': 0.03,
#     'uvIndex': 10,
#     'uvIndexTime': 1561924800,
#     'visibility': 10,
#     'ozone': 325.4,
#     'temperatureMin': 54.62,
#     'temperatureMinTime': 1561896000,
#     'temperatureMax': 68.1,
#     'temperatureMaxTime': 1561932000,
#     'apparentTemperatureMin': 54.62,
#     'apparentTemperatureMinTime': 1561896000,
#     'apparentTemperatureMax': 68.1,
#     'apparentTemperatureMaxTime': 1561932000},
#    {'time': 1561964400,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1561985556,
#     'sunsetTime': 1562038618,
#     'moonPhase': 0.98,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0004,
#     'precipIntensityMaxTime': 1561989600,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 64.94,
#     'temperatureHighTime': 1562018400,
#     'temperatureLow': 54.89,
#     'temperatureLowTime': 1562065200,
#     'apparentTemperatureHigh': 64.94,
#     'apparentTemperatureHighTime': 1562018400,
#     'apparentTemperatureLow': 54.89,
#     'apparentTemperatureLowTime': 1562065200,
#     'dewPoint': 52.08,
#     'humidity': 0.8,
#     'pressure': 1014.65,
#     'windSpeed': 6.83,
#     'windGust': 18.25,
#     'windGustTime': 1562025600,
#     'windBearing': 229,
#     'cloudCover': 0.04,
#     'uvIndex': 10,
#     'uvIndexTime': 1562011200,
#     'visibility': 10,
#     'ozone': 310.5,
#     'temperatureMin': 53.01,
#     'temperatureMinTime': 1561982400,
#     'temperatureMax': 64.94,
#     'temperatureMaxTime': 1562018400,
#     'apparentTemperatureMin': 53.01,
#     'apparentTemperatureMinTime': 1561982400,
#     'apparentTemperatureMax': 64.94,
#     'apparentTemperatureMaxTime': 1562018400}]},
#  'flags': {'sources': ['nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky',
#    'nearest-precip'],
#   'nearest-station': 1.835,
#   'units': 'us'},
#  'offset': -7}

# %%
from datetime import datetime
timestamp = 1545730073
dt_object = datetime.fromtimestamp(timestamp)
print("dt_object =", dt_object)
print("type(dt_object) =", type(dt_object))
# Out:
# dt_object = 2018-12-25 04:27:53
# type(dt_object) = <class 'datetime.datetime'>

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
temperature = data['currently']['temperature']
summary = data['currently']['summary']
today = data['daily']['data'][0]
temp_feeling = 'warm'
high_temp = today['temperatureHigh']
low_temp = today['temperatureLow']

# %%
print(f'Right now it is {temperature} degrees out and {summary}. \
Today will be {temp_feeling} with a high of {high_temp} and a low of {low_temp}. \
RAIN_WARNING.')
# Out:
# Right now it is 62.37 degrees out and Mostly Cloudy. Today will be warm with a high of 67.73 and a low of 56.87. RAIN_WARNING.

# %%
import datetime
right_now = datetime.datetime.now()
date_string = right_now.strftime("%B %d, %Y")
date_string
# Out:
# 'June 24, 2019'

# %%
api_key = os.getenv('mailgun_api_key')

# %%
response = requests.post("https://api.mailgun.net/v3/SANDBOX60ABF18F48944CD784D206060B22489E.MAILGUN.ORG/messages",
                         auth=("api", api_key),
                         data={"from": "DYN.ACD@GMAIL.COM",
                               "to": ["DYN.ACD@GMAIL.COM"],
                               "subject": "8AM Weather forecast:.",
                               "text": "Good Morning! Here is today's weather forecast."})
response.text
# Out:
# 'Forbidden'
