# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
API_KEY = os.getenv("dark_sky_api_key")
url = f'https://api.darksky.net/forecast/{API_KEY}/37.8267,-122.4233'

response = requests.get(url)
data = response.json()
data
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1561406543,
#   'summary': 'Partly Cloudy',
#   'icon': 'partly-cloudy-day',
#   'nearestStormDistance': 0,
#   'precipIntensity': 0.002,
#   'precipIntensityError': 0,
#   'precipProbability': 0.08,
#   'precipType': 'rain',
#   'temperature': 66.29,
#   'apparentTemperature': 66.29,
#   'dewPoint': 55.84,
#   'humidity': 0.69,
#   'pressure': 1011.49,
#   'windSpeed': 6.13,
#   'windGust': 10.99,
#   'windBearing': 269,
#   'cloudCover': 0.32,
#   'uvIndex': 8,
#   'visibility': 7.927,
#   'ozone': 332.5},
#  'minutely': {'summary': 'Partly cloudy for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1561406520,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0,
#     'precipProbability': 0.07,
#     'precipType': 'rain'},
#    {'time': 1561406580,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.1,
#     'precipType': 'rain'},
#    {'time': 1561406640,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.11,
#     'precipType': 'rain'},
#    {'time': 1561406700,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.11,
#     'precipType': 'rain'},
#    {'time': 1561406760,
#     'precipIntensity': 0.002,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1561406820,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1561406880,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1561406940,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1561407000,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1561407060,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1561407120,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1561407180,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1561407240,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.22,
#     'precipType': 'rain'},
#    {'time': 1561407300,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.23,
#     'precipType': 'rain'},
#    {'time': 1561407360,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1561407420,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561407480,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1561407540,
#     'precipIntensity': 0.004,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1561407600,
#     'precipIntensity': 0.004,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561407660,
#     'precipIntensity': 0.004,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.26,
#     'precipType': 'rain'},
#    {'time': 1561407720,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561407780,
#     'precipIntensity': 0.004,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1561407840,
#     'precipIntensity': 0.004,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561407900,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561407960,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561408020,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.24,
#     'precipType': 'rain'},
#    {'time': 1561408080,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.25,
#     'precipType': 'rain'},
#    {'time': 1561408140,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.23,
#     'precipType': 'rain'},
#    {'time': 1561408200,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.23,
#     'precipType': 'rain'},
#    {'time': 1561408260,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.22,
#     'precipType': 'rain'},
#    {'time': 1561408320,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1561408380,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1561408440,
#     'precipIntensity': 0.004,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1561408500,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1561408560,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.21,
#     'precipType': 'rain'},
#    {'time': 1561408620,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.2,
#     'precipType': 'rain'},
#    {'time': 1561408680,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.19,
#     'precipType': 'rain'},
#    {'time': 1561408740,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.19,
#     'precipType': 'rain'},
#    {'time': 1561408800,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1561408860,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1561408920,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1561408980,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.18,
#     'precipType': 'rain'},
#    {'time': 1561409040,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1561409100,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.17,
#     'precipType': 'rain'},
#    {'time': 1561409160,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1561409220,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1561409280,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.16,
#     'precipType': 'rain'},
#    {'time': 1561409340,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1561409400,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1561409460,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1561409520,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.15,
#     'precipType': 'rain'},
#    {'time': 1561409580,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1561409640,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1561409700,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1561409760,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.14,
#     'precipType': 'rain'},
#    {'time': 1561409820,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1561409880,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1561409940,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1561410000,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.12,
#     'precipType': 'rain'},
#    {'time': 1561410060,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.002,
#     'precipProbability': 0.13,
#     'precipType': 'rain'},
#    {'time': 1561410120,
#     'precipIntensity': 0.003,
#     'precipIntensityError': 0.001,
#     'precipProbability': 0.13,
#     'precipType': 'rain'}]},
#  'hourly': {'summary': 'Partly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1561406400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.26,
#     'precipType': 'rain',
#     'temperature': 66.26,
#     'apparentTemperature': 66.26,
#     'dewPoint': 55.87,
#     'humidity': 0.69,
#     'pressure': 1011.5,
#     'windSpeed': 6.09,
#     'windGust': 10.94,
#     'windBearing': 270,
#     'cloudCover': 0.32,
#     'uvIndex': 8,
#     'visibility': 7.865,
#     'ozone': 332.5},
#    {'time': 1561410000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.22,
#     'precipType': 'rain',
#     'temperature': 67.1,
#     'apparentTemperature': 67.1,
#     'dewPoint': 55.22,
#     'humidity': 0.66,
#     'pressure': 1011.17,
#     'windSpeed': 6.93,
#     'windGust': 12.12,
#     'windBearing': 261,
#     'cloudCover': 0.37,
#     'uvIndex': 7,
#     'visibility': 9.448,
#     'ozone': 333.2},
#    {'time': 1561413600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 66.14,
#     'apparentTemperature': 66.14,
#     'dewPoint': 53.67,
#     'humidity': 0.64,
#     'pressure': 1010.84,
#     'windSpeed': 9.37,
#     'windGust': 13.56,
#     'windBearing': 247,
#     'cloudCover': 0.6,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 334},
#    {'time': 1561417200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 65.28,
#     'apparentTemperature': 65.28,
#     'dewPoint': 52.58,
#     'humidity': 0.64,
#     'pressure': 1010.47,
#     'windSpeed': 9.95,
#     'windGust': 14.63,
#     'windBearing': 242,
#     'cloudCover': 0.72,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 334.9},
#    {'time': 1561420800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 64.23,
#     'apparentTemperature': 64.23,
#     'dewPoint': 52.36,
#     'humidity': 0.65,
#     'pressure': 1009.92,
#     'windSpeed': 10.73,
#     'windGust': 15.1,
#     'windBearing': 244,
#     'cloudCover': 0.74,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 335.2},
#    {'time': 1561424400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 62.63,
#     'apparentTemperature': 62.63,
#     'dewPoint': 52.23,
#     'humidity': 0.69,
#     'pressure': 1009.76,
#     'windSpeed': 9.8,
#     'windGust': 14.88,
#     'windBearing': 242,
#     'cloudCover': 0.77,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 334.7},
#    {'time': 1561428000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.15,
#     'apparentTemperature': 61.15,
#     'dewPoint': 52.15,
#     'humidity': 0.72,
#     'pressure': 1009.47,
#     'windSpeed': 9.22,
#     'windGust': 14.21,
#     'windBearing': 239,
#     'cloudCover': 0.8,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.8},
#    {'time': 1561431600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.62,
#     'apparentTemperature': 60.62,
#     'dewPoint': 52.06,
#     'humidity': 0.73,
#     'pressure': 1009.55,
#     'windSpeed': 8.66,
#     'windGust': 13.33,
#     'windBearing': 240,
#     'cloudCover': 0.83,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.2},
#    {'time': 1561435200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 60.43,
#     'apparentTemperature': 60.43,
#     'dewPoint': 51.93,
#     'humidity': 0.74,
#     'pressure': 1009.62,
#     'windSpeed': 8.16,
#     'windGust': 12.75,
#     'windBearing': 237,
#     'cloudCover': 0.85,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.3},
#    {'time': 1561438800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.22,
#     'apparentTemperature': 60.22,
#     'dewPoint': 51.86,
#     'humidity': 0.74,
#     'pressure': 1009.86,
#     'windSpeed': 7.93,
#     'windGust': 12.3,
#     'windBearing': 233,
#     'cloudCover': 0.86,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 333.9},
#    {'time': 1561442400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.91,
#     'apparentTemperature': 59.91,
#     'dewPoint': 51.7,
#     'humidity': 0.74,
#     'pressure': 1010.06,
#     'windSpeed': 7.76,
#     'windGust': 12.3,
#     'windBearing': 230,
#     'cloudCover': 0.87,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.3},
#    {'time': 1561446000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.8,
#     'apparentTemperature': 59.8,
#     'dewPoint': 51.63,
#     'humidity': 0.74,
#     'pressure': 1009.96,
#     'windSpeed': 7.5,
#     'windGust': 12.01,
#     'windBearing': 227,
#     'cloudCover': 0.88,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.2},
#    {'time': 1561449600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.001,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 59.65,
#     'apparentTemperature': 59.65,
#     'dewPoint': 51.48,
#     'humidity': 0.74,
#     'pressure': 1009.76,
#     'windSpeed': 7.63,
#     'windGust': 11.72,
#     'windBearing': 226,
#     'cloudCover': 0.88,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.1},
#    {'time': 1561453200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.02,
#     'apparentTemperature': 59.02,
#     'dewPoint': 51.8,
#     'humidity': 0.77,
#     'pressure': 1009.47,
#     'windSpeed': 6.46,
#     'windGust': 9.8,
#     'windBearing': 234,
#     'cloudCover': 0.82,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 334.7},
#    {'time': 1561456800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.77,
#     'apparentTemperature': 58.77,
#     'dewPoint': 51.59,
#     'humidity': 0.77,
#     'pressure': 1009.33,
#     'windSpeed': 6.4,
#     'windGust': 9.79,
#     'windBearing': 227,
#     'cloudCover': 0.73,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 336.8},
#    {'time': 1561460400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.1,
#     'apparentTemperature': 58.1,
#     'dewPoint': 51.34,
#     'humidity': 0.78,
#     'pressure': 1009.39,
#     'windSpeed': 6.37,
#     'windGust': 9.96,
#     'windBearing': 255,
#     'cloudCover': 0.63,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 339.6},
#    {'time': 1561464000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.08,
#     'apparentTemperature': 57.08,
#     'dewPoint': 50.89,
#     'humidity': 0.8,
#     'pressure': 1009.41,
#     'windSpeed': 6.25,
#     'windGust': 9.89,
#     'windBearing': 246,
#     'cloudCover': 0.46,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 341.6},
#    {'time': 1561467600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.44,
#     'apparentTemperature': 57.44,
#     'dewPoint': 51.17,
#     'humidity': 0.8,
#     'pressure': 1009.66,
#     'windSpeed': 5.77,
#     'windGust': 9.22,
#     'windBearing': 246,
#     'cloudCover': 0.29,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 342},
#    {'time': 1561471200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.34,
#     'apparentTemperature': 58.34,
#     'dewPoint': 51.24,
#     'humidity': 0.77,
#     'pressure': 1009.91,
#     'windSpeed': 5.22,
#     'windGust': 8.33,
#     'windBearing': 246,
#     'cloudCover': 0.2,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 341.6},
#    {'time': 1561474800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.75,
#     'apparentTemperature': 59.75,
#     'dewPoint': 51.14,
#     'humidity': 0.73,
#     'pressure': 1010.18,
#     'windSpeed': 5.11,
#     'windGust': 7.92,
#     'windBearing': 247,
#     'cloudCover': 0.13,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 341.1},
#    {'time': 1561478400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.3,
#     'apparentTemperature': 61.3,
#     'dewPoint': 51.41,
#     'humidity': 0.7,
#     'pressure': 1010.54,
#     'windSpeed': 5.47,
#     'windGust': 8.21,
#     'windBearing': 248,
#     'cloudCover': 0.1,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 340.4},
#    {'time': 1561482000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.21,
#     'apparentTemperature': 63.21,
#     'dewPoint': 51.5,
#     'humidity': 0.66,
#     'pressure': 1010.8,
#     'windSpeed': 6.36,
#     'windGust': 8.98,
#     'windBearing': 252,
#     'cloudCover': 0.09,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 339.4},
#    {'time': 1561485600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.83,
#     'apparentTemperature': 64.83,
#     'dewPoint': 51.58,
#     'humidity': 0.62,
#     'pressure': 1011.04,
#     'windSpeed': 7.38,
#     'windGust': 10.19,
#     'windBearing': 250,
#     'cloudCover': 0.09,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 338.7},
#    {'time': 1561489200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.04,
#     'apparentTemperature': 66.04,
#     'dewPoint': 51.85,
#     'humidity': 0.6,
#     'pressure': 1011.2,
#     'windSpeed': 8.71,
#     'windGust': 12.03,
#     'windBearing': 240,
#     'cloudCover': 0.25,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 338.3},
#    {'time': 1561492800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.91,
#     'apparentTemperature': 66.91,
#     'dewPoint': 52.12,
#     'humidity': 0.59,
#     'pressure': 1011.23,
#     'windSpeed': 10.26,
#     'windGust': 14.32,
#     'windBearing': 282,
#     'cloudCover': 0.25,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 338.2},
#    {'time': 1561496400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.38,
#     'apparentTemperature': 67.38,
#     'dewPoint': 52.09,
#     'humidity': 0.58,
#     'pressure': 1011.21,
#     'windSpeed': 10.69,
#     'windGust': 16.35,
#     'windBearing': 261,
#     'cloudCover': 0.26,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 338.1},
#    {'time': 1561500000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.32,
#     'apparentTemperature': 67.32,
#     'dewPoint': 52.37,
#     'humidity': 0.59,
#     'pressure': 1011.16,
#     'windSpeed': 11.4,
#     'windGust': 18.03,
#     'windBearing': 257,
#     'cloudCover': 0.38,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 338.2},
#    {'time': 1561503600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.96,
#     'apparentTemperature': 66.96,
#     'dewPoint': 52.34,
#     'humidity': 0.59,
#     'pressure': 1011.06,
#     'windSpeed': 13.08,
#     'windGust': 19.44,
#     'windBearing': 270,
#     'cloudCover': 0.39,
#     'uvIndex': 5,
#     'visibility': 10,
#     'ozone': 338.5},
#    {'time': 1561507200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.76,
#     'apparentTemperature': 65.76,
#     'dewPoint': 52.65,
#     'humidity': 0.63,
#     'pressure': 1010.92,
#     'windSpeed': 13.43,
#     'windGust': 20.27,
#     'windBearing': 274,
#     'cloudCover': 0.42,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 338.9},
#    {'time': 1561510800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 64.2,
#     'apparentTemperature': 64.2,
#     'dewPoint': 52.26,
#     'humidity': 0.65,
#     'pressure': 1010.97,
#     'windSpeed': 12.12,
#     'windGust': 20.28,
#     'windBearing': 268,
#     'cloudCover': 0.43,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 339.4},
#    {'time': 1561514400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.97,
#     'apparentTemperature': 61.97,
#     'dewPoint': 52.18,
#     'humidity': 0.7,
#     'pressure': 1011.02,
#     'windSpeed': 11.81,
#     'windGust': 19.68,
#     'windBearing': 271,
#     'cloudCover': 0.43,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 340},
#    {'time': 1561518000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.91,
#     'apparentTemperature': 60.91,
#     'dewPoint': 52.61,
#     'humidity': 0.74,
#     'pressure': 1011.21,
#     'windSpeed': 11.39,
#     'windGust': 18.8,
#     'windBearing': 268,
#     'cloudCover': 0.41,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 340.8},
#    {'time': 1561521600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.03,
#     'apparentTemperature': 60.03,
#     'dewPoint': 51.92,
#     'humidity': 0.75,
#     'pressure': 1011.85,
#     'windSpeed': 10.6,
#     'windGust': 17.48,
#     'windBearing': 270,
#     'cloudCover': 0.24,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 341.9},
#    {'time': 1561525200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.32,
#     'apparentTemperature': 59.32,
#     'dewPoint': 51.74,
#     'humidity': 0.76,
#     'pressure': 1012.61,
#     'windSpeed': 11.35,
#     'windGust': 15.87,
#     'windBearing': 271,
#     'cloudCover': 0.31,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 343.2},
#    {'time': 1561528800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.32,
#     'apparentTemperature': 58.32,
#     'dewPoint': 52.17,
#     'humidity': 0.8,
#     'pressure': 1013.07,
#     'windSpeed': 9.4,
#     'windGust': 14.69,
#     'windBearing': 269,
#     'cloudCover': 0.26,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.1},
#    {'time': 1561532400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.88,
#     'apparentTemperature': 57.88,
#     'dewPoint': 51.41,
#     'humidity': 0.79,
#     'pressure': 1013.27,
#     'windSpeed': 9.19,
#     'windGust': 14.42,
#     'windBearing': 269,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.6},
#    {'time': 1561536000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.35,
#     'apparentTemperature': 57.35,
#     'dewPoint': 51.26,
#     'humidity': 0.8,
#     'pressure': 1013.22,
#     'windSpeed': 10.32,
#     'windGust': 14.59,
#     'windBearing': 267,
#     'cloudCover': 0.3,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.8},
#    {'time': 1561539600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.63,
#     'apparentTemperature': 56.63,
#     'dewPoint': 51.52,
#     'humidity': 0.83,
#     'pressure': 1013.14,
#     'windSpeed': 8.73,
#     'windGust': 14.58,
#     'windBearing': 266,
#     'cloudCover': 0.48,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.9},
#    {'time': 1561543200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.47,
#     'apparentTemperature': 56.47,
#     'dewPoint': 50.94,
#     'humidity': 0.82,
#     'pressure': 1013.15,
#     'windSpeed': 8.46,
#     'windGust': 14.13,
#     'windBearing': 264,
#     'cloudCover': 0.53,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.9},
#    {'time': 1561546800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56,
#     'apparentTemperature': 56,
#     'dewPoint': 50.75,
#     'humidity': 0.83,
#     'pressure': 1013.14,
#     'windSpeed': 9.35,
#     'windGust': 13.49,
#     'windBearing': 263,
#     'cloudCover': 0.55,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.7},
#    {'time': 1561550400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.05,
#     'apparentTemperature': 55.05,
#     'dewPoint': 50.87,
#     'humidity': 0.86,
#     'pressure': 1013.21,
#     'windSpeed': 7.75,
#     'windGust': 12.82,
#     'windBearing': 264,
#     'cloudCover': 0.34,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.6},
#    {'time': 1561554000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.23,
#     'apparentTemperature': 55.23,
#     'dewPoint': 50.6,
#     'humidity': 0.84,
#     'pressure': 1013.51,
#     'windSpeed': 7.62,
#     'windGust': 12.01,
#     'windBearing': 262,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.4},
#    {'time': 1561557600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.9,
#     'apparentTemperature': 55.9,
#     'dewPoint': 50.64,
#     'humidity': 0.82,
#     'pressure': 1013.91,
#     'windSpeed': 7.57,
#     'windGust': 11.21,
#     'windBearing': 257,
#     'cloudCover': 0.27,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 344.1},
#    {'time': 1561561200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.28,
#     'apparentTemperature': 57.28,
#     'dewPoint': 51.02,
#     'humidity': 0.8,
#     'pressure': 1014.27,
#     'windSpeed': 7.78,
#     'windGust': 10.78,
#     'windBearing': 263,
#     'cloudCover': 0.26,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 343.9},
#    {'time': 1561564800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.23,
#     'apparentTemperature': 58.23,
#     'dewPoint': 50.82,
#     'humidity': 0.76,
#     'pressure': 1014.69,
#     'windSpeed': 8.97,
#     'windGust': 10.93,
#     'windBearing': 276,
#     'cloudCover': 0.27,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 343.7},
#    {'time': 1561568400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.3,
#     'apparentTemperature': 59.3,
#     'dewPoint': 50.97,
#     'humidity': 0.74,
#     'pressure': 1015.04,
#     'windSpeed': 9.83,
#     'windGust': 11.48,
#     'windBearing': 254,
#     'cloudCover': 0.27,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 343.5},
#    {'time': 1561572000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.31,
#     'apparentTemperature': 60.31,
#     'dewPoint': 51.75,
#     'humidity': 0.73,
#     'pressure': 1015.34,
#     'windSpeed': 10.73,
#     'windGust': 12.3,
#     'windBearing': 262,
#     'cloudCover': 0.27,
#     'uvIndex': 6,
#     'visibility': 10,
#     'ozone': 343.4},
#    {'time': 1561575600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.69,
#     'apparentTemperature': 60.69,
#     'dewPoint': 51.49,
#     'humidity': 0.72,
#     'pressure': 1015.74,
#     'windSpeed': 11.07,
#     'windGust': 13.48,
#     'windBearing': 255,
#     'cloudCover': 0.23,
#     'uvIndex': 7,
#     'visibility': 10,
#     'ozone': 343.3},
#    {'time': 1561579200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.75,
#     'apparentTemperature': 61.75,
#     'dewPoint': 51.89,
#     'humidity': 0.7,
#     'pressure': 1015.99,
#     'windSpeed': 11.98,
#     'windGust': 14.9,
#     'windBearing': 270,
#     'cloudCover': 0.19,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 343.2},
#    {'time': 1561582800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.77,
#     'apparentTemperature': 62.77,
#     'dewPoint': 52.45,
#     'humidity': 0.69,
#     'pressure': 1015.94,
#     'windSpeed': 12.59,
#     'windGust': 16.17,
#     'windBearing': 265,
#     'cloudCover': 0.14,
#     'uvIndex': 8,
#     'visibility': 10,
#     'ozone': 343.1}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures falling to 63°F on Thursday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1561359600,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561380600,
#     'sunsetTime': 1561433813,
#     'moonPhase': 0.74,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0016,
#     'precipIntensityMaxTime': 1561424400,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperatureHigh': 67.1,
#     'temperatureHighTime': 1561410000,
#     'temperatureLow': 57.08,
#     'temperatureLowTime': 1561464000,
#     'apparentTemperatureHigh': 67.1,
#     'apparentTemperatureHighTime': 1561410000,
#     'apparentTemperatureLow': 57.08,
#     'apparentTemperatureLowTime': 1561464000,
#     'dewPoint': 52.91,
#     'humidity': 0.77,
#     'pressure': 1011.19,
#     'windSpeed': 6.86,
#     'windGust': 15.1,
#     'windGustTime': 1561420800,
#     'windBearing': 244,
#     'cloudCover': 0.58,
#     'uvIndex': 8,
#     'uvIndexTime': 1561406400,
#     'visibility': 8.584,
#     'ozone': 332.9,
#     'temperatureMin': 55.28,
#     'temperatureMinTime': 1561384800,
#     'temperatureMax': 67.1,
#     'temperatureMaxTime': 1561410000,
#     'apparentTemperatureMin': 55.28,
#     'apparentTemperatureMinTime': 1561384800,
#     'apparentTemperatureMax': 67.1,
#     'apparentTemperatureMaxTime': 1561410000},
#    {'time': 1561446000,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561467018,
#     'sunsetTime': 1561520219,
#     'moonPhase': 0.77,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0015,
#     'precipIntensityMaxTime': 1561449600,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperatureHigh': 67.38,
#     'temperatureHighTime': 1561496400,
#     'temperatureLow': 55.05,
#     'temperatureLowTime': 1561550400,
#     'apparentTemperatureHigh': 67.38,
#     'apparentTemperatureHighTime': 1561496400,
#     'apparentTemperatureLow': 55.05,
#     'apparentTemperatureLowTime': 1561550400,
#     'dewPoint': 51.78,
#     'humidity': 0.71,
#     'pressure': 1010.81,
#     'windSpeed': 8.77,
#     'windGust': 20.28,
#     'windGustTime': 1561510800,
#     'windBearing': 259,
#     'cloudCover': 0.38,
#     'uvIndex': 8,
#     'uvIndexTime': 1561492800,
#     'visibility': 10,
#     'ozone': 339.5,
#     'temperatureMin': 57.08,
#     'temperatureMinTime': 1561464000,
#     'temperatureMax': 67.38,
#     'temperatureMaxTime': 1561496400,
#     'apparentTemperatureMin': 57.08,
#     'apparentTemperatureMinTime': 1561464000,
#     'apparentTemperatureMax': 67.38,
#     'apparentTemperatureMaxTime': 1561496400},
#    {'time': 1561532400,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561553437,
#     'sunsetTime': 1561606623,
#     'moonPhase': 0.8,
#     'precipIntensity': 0.0002,
#     'precipIntensityMax': 0.0005,
#     'precipIntensityMaxTime': 1561539600,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 62.77,
#     'temperatureHighTime': 1561582800,
#     'temperatureLow': 53.71,
#     'temperatureLowTime': 1561636800,
#     'apparentTemperatureHigh': 62.77,
#     'apparentTemperatureHighTime': 1561582800,
#     'apparentTemperatureLow': 53.71,
#     'apparentTemperatureLowTime': 1561636800,
#     'dewPoint': 51.48,
#     'humidity': 0.78,
#     'pressure': 1015.1,
#     'windSpeed': 10.29,
#     'windGust': 18.59,
#     'windGustTime': 1561593600,
#     'windBearing': 268,
#     'cloudCover': 0.28,
#     'uvIndex': 8,
#     'uvIndexTime': 1561582800,
#     'visibility': 10,
#     'ozone': 343.6,
#     'temperatureMin': 55.05,
#     'temperatureMinTime': 1561550400,
#     'temperatureMax': 62.77,
#     'temperatureMaxTime': 1561582800,
#     'apparentTemperatureMin': 55.05,
#     'apparentTemperatureMinTime': 1561550400,
#     'apparentTemperatureMax': 62.77,
#     'apparentTemperatureMaxTime': 1561582800},
#    {'time': 1561618800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561639858,
#     'sunsetTime': 1561693026,
#     'moonPhase': 0.84,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0006,
#     'precipIntensityMaxTime': 1561636800,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperatureHigh': 62.62,
#     'temperatureHighTime': 1561672800,
#     'temperatureLow': 52.65,
#     'temperatureLowTime': 1561723200,
#     'apparentTemperatureHigh': 62.62,
#     'apparentTemperatureHighTime': 1561672800,
#     'apparentTemperatureLow': 52.65,
#     'apparentTemperatureLowTime': 1561723200,
#     'dewPoint': 50.34,
#     'humidity': 0.77,
#     'pressure': 1017.81,
#     'windSpeed': 10.87,
#     'windGust': 22.2,
#     'windGustTime': 1561687200,
#     'windBearing': 281,
#     'cloudCover': 0.74,
#     'uvIndex': 6,
#     'uvIndexTime': 1561665600,
#     'visibility': 10,
#     'ozone': 349.4,
#     'temperatureMin': 53.71,
#     'temperatureMinTime': 1561636800,
#     'temperatureMax': 62.62,
#     'temperatureMaxTime': 1561672800,
#     'apparentTemperatureMin': 53.71,
#     'apparentTemperatureMinTime': 1561636800,
#     'apparentTemperatureMax': 62.62,
#     'apparentTemperatureMaxTime': 1561672800},
#    {'time': 1561705200,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1561726281,
#     'sunsetTime': 1561779426,
#     'moonPhase': 0.87,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipProbability': 0,
#     'temperatureHigh': 65.36,
#     'temperatureHighTime': 1561759200,
#     'temperatureLow': 52.79,
#     'temperatureLowTime': 1561809600,
#     'apparentTemperatureHigh': 65.36,
#     'apparentTemperatureHighTime': 1561759200,
#     'apparentTemperatureLow': 52.79,
#     'apparentTemperatureLowTime': 1561809600,
#     'dewPoint': 49.33,
#     'humidity': 0.71,
#     'pressure': 1017.39,
#     'windSpeed': 9.23,
#     'windGust': 21.79,
#     'windGustTime': 1561766400,
#     'windBearing': 283,
#     'cloudCover': 0.26,
#     'uvIndex': 8,
#     'uvIndexTime': 1561752000,
#     'visibility': 10,
#     'ozone': 377.3,
#     'temperatureMin': 52.65,
#     'temperatureMinTime': 1561723200,
#     'temperatureMax': 65.36,
#     'temperatureMaxTime': 1561759200,
#     'apparentTemperatureMin': 52.65,
#     'apparentTemperatureMinTime': 1561723200,
#     'apparentTemperatureMax': 65.36,
#     'apparentTemperatureMaxTime': 1561759200},
#    {'time': 1561791600,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561812704,
#     'sunsetTime': 1561865825,
#     'moonPhase': 0.9,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1561798800,
#     'precipProbability': 0.01,
#     'temperatureHigh': 64.28,
#     'temperatureHighTime': 1561845600,
#     'temperatureLow': 53.37,
#     'temperatureLowTime': 1561896000,
#     'apparentTemperatureHigh': 64.28,
#     'apparentTemperatureHighTime': 1561845600,
#     'apparentTemperatureLow': 53.37,
#     'apparentTemperatureLowTime': 1561896000,
#     'dewPoint': 50.94,
#     'humidity': 0.78,
#     'pressure': 1016.82,
#     'windSpeed': 6.61,
#     'windGust': 17.8,
#     'windGustTime': 1561852800,
#     'windBearing': 245,
#     'cloudCover': 0.13,
#     'uvIndex': 8,
#     'uvIndexTime': 1561842000,
#     'visibility': 10,
#     'ozone': 351.2,
#     'temperatureMin': 52.79,
#     'temperatureMinTime': 1561809600,
#     'temperatureMax': 64.28,
#     'temperatureMaxTime': 1561845600,
#     'apparentTemperatureMin': 52.79,
#     'apparentTemperatureMinTime': 1561809600,
#     'apparentTemperatureMax': 64.28,
#     'apparentTemperatureMaxTime': 1561845600},
#    {'time': 1561878000,
#     'summary': 'Partly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1561899130,
#     'sunsetTime': 1561952222,
#     'moonPhase': 0.94,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0005,
#     'precipIntensityMaxTime': 1561906800,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 66.37,
#     'temperatureHighTime': 1561932000,
#     'temperatureLow': 53.22,
#     'temperatureLowTime': 1561978800,
#     'apparentTemperatureHigh': 66.37,
#     'apparentTemperatureHighTime': 1561932000,
#     'apparentTemperatureLow': 53.22,
#     'apparentTemperatureLowTime': 1561978800,
#     'dewPoint': 50.92,
#     'humidity': 0.77,
#     'pressure': 1016.9,
#     'windSpeed': 5.89,
#     'windGust': 16.08,
#     'windGustTime': 1561942800,
#     'windBearing': 237,
#     'cloudCover': 0.38,
#     'uvIndex': 5,
#     'uvIndexTime': 1561921200,
#     'visibility': 10,
#     'ozone': 318.7,
#     'temperatureMin': 53.37,
#     'temperatureMinTime': 1561896000,
#     'temperatureMax': 66.37,
#     'temperatureMaxTime': 1561932000,
#     'apparentTemperatureMin': 53.37,
#     'apparentTemperatureMinTime': 1561896000,
#     'apparentTemperatureMax': 66.37,
#     'apparentTemperatureMaxTime': 1561932000},
#    {'time': 1561964400,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1561985556,
#     'sunsetTime': 1562038618,
#     'moonPhase': 0.98,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0005,
#     'precipIntensityMaxTime': 1561993200,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 65.27,
#     'temperatureHighTime': 1562018400,
#     'temperatureLow': 53.62,
#     'temperatureLowTime': 1562065200,
#     'apparentTemperatureHigh': 65.27,
#     'apparentTemperatureHighTime': 1562018400,
#     'apparentTemperatureLow': 53.62,
#     'apparentTemperatureLowTime': 1562065200,
#     'dewPoint': 51.57,
#     'humidity': 0.79,
#     'pressure': 1015.15,
#     'windSpeed': 6.8,
#     'windGust': 17.15,
#     'windGustTime': 1562032800,
#     'windBearing': 229,
#     'cloudCover': 0.14,
#     'uvIndex': 10,
#     'uvIndexTime': 1562011200,
#     'visibility': 10,
#     'ozone': 308.3,
#     'temperatureMin': 53.22,
#     'temperatureMinTime': 1561978800,
#     'temperatureMax': 65.27,
#     'temperatureMaxTime': 1562018400,
#     'apparentTemperatureMin': 53.22,
#     'apparentTemperatureMinTime': 1561978800,
#     'apparentTemperatureMax': 65.27,
#     'apparentTemperatureMaxTime': 1562018400}]},
#  'flags': {'sources': ['nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky',
#    'nearest-precip'],
#   'nearest-station': 1.835,
#   'units': 'us'},
#  'offset': -7}

# %%
from datetime import datetime
timestamp = 1545730073
dt_object = datetime.fromtimestamp(timestamp)
print("dt_object =", dt_object)
print("type(dt_object) =", type(dt_object))

# %%
data.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])

# %%
temperature = data['currently']['temperature']
summary = data['currently']['summary']
today = data['daily']['data'][0]
temp_feeling = 'warm'
high_temp = today['temperatureHigh']
low_temp = today['temperatureLow']

# %%
print(f'Right now it is {temperature} degrees out and {summary}. \
Today will be {temp_feeling} with a high of {high_temp} and a low of {low_temp}. \
RAIN_WARNING.')

# %%
import datetime
right_now = datetime.datetime.now()
date_string = right_now.strftime("%B %d, %Y")
date_string
# Out:
# 'June 24, 2019'

# %%
api_key = 'mailgun_api_key

# %%
response = requests.post("https://api.mailgun.net/v3/SANDBOX60ABF18F48944CD784D206060B22489E.MAILGUN.ORG/messages",
                         auth=("api", api_key),
                         data={"from": "DYN.ACD@GMAIL.COM",
                               "to": ["DYN.ACD@GMAIL.COM"],
                               "subject": "8AM Weather forecast:.",
                               "text": "Good Morning! Here is today's weather forecast."})
response.text
# Out:
# '{\n  "message": "exposed account credentials"\n}'
